# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file=pd.read_csv("mitbih_database/100.csv")

# %%
file.columns
# Out:
# Index([''sample #'', ''MLII'', ''V5''], dtype='object')

# %%
signal=file.iloc[:18,1]

# %%
plt.plot(signal)
